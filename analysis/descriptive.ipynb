# %%
import pandas as pd

# Load data
data_hyp1 = pd.read_csv('../data/final/data_panel_hyp1.csv')
data_hyp2 = pd.read_csv('../data/final/data_panel_hyp2.csv')
data_hyp3 = pd.read_csv('../data/final/data_panel_hyp3.csv')
data_hyp4 = pd.read_csv('../data/final/data_panel_hyp4.csv')
data_hyp5 = pd.read_csv('../data/final/data_panel_hyp5.csv')

# %%
# Create descriptive statistics for core variables
core_vars = ['Age', 'Min', 'Overall_Performance_Index', 'Team_Rating', 
            'Latest_Transfer_Fee', 'Log_MV1', 'MV_Change']

desc_stats = data_hyp1[core_vars].describe()

# Format the output
desc_stats = desc_stats.round(3)
print("\nTable 1: Core Variables Descriptive Statistics")
print("---------------------------------------------")
desc_stats
# Out:
# Table 1: Core Variables Descriptive Statistics
# ---------------------------------------------
#             Age       Min  Overall_Performance_Index  Team_Rating  \
# count  4488.000  4488.000                   4488.000     4488.000
# mean      0.000    -0.000                      0.000        0.000
# std       1.000     1.000                      0.999        1.000
# min      -2.357    -1.987                     -9.789       -2.800
# 25%      -0.809    -0.787                     -0.602       -0.744
# 50%      -0.034     0.042                     -0.028       -0.186
# 75%       0.740     0.833                      0.624        0.584
# max       4.094     1.859                      6.428        2.611
#
#        Latest_Transfer_Fee   Log_MV1  MV_Change
# count             4488.000  4488.000   4488.000
# mean                 0.000    -0.000      0.051
# std                  1.000     1.000      0.585
# min                 -0.597    -3.498     -1.792
# ...

# %%
# Create descriptive statistics for interaction variables
interaction_vars = ['Perf_MV1_Interaction', 'Underperformance_Magnitude', 
                   'Underperformer_Log_MV1_Interaction']

desc_stats_interactions = data_hyp1[interaction_vars].describe()

# Format the output
desc_stats_interactions = desc_stats_interactions.round(3)
print("\nTable 2: Performance and Market Value Interactions")
print("------------------------------------------------")
desc_stats_interactions
# Out:
# Table 2: Performance and Market Value Interactions
# ------------------------------------------------
#        Perf_MV1_Interaction  Underperformance_Magnitude  \
# count              4488.000                    4488.000
# mean                  0.388                       0.379
# std                   1.115                       0.606
# min                  -7.026                       0.000
# 25%                  -0.098                       0.000
# 50%                   0.122                       0.028
# 75%                   0.664                       0.602
# max                  21.680                       9.789
#
#        Underperformer_Log_MV1_Interaction
# count                            4488.000
# mean                               -0.186
# std                                 0.836
# min                               -21.680
# 25%                                -0.101
# 50%                                 0.000
# 75%                                 0.000
# ...

# %%
Table 2: Performance and Market Value Interactions

Perf_MV1_Interaction
Underperformance_Magnitude
Underperformer_Log_MV1_Interaction
Expected_Future_Performance
Expected_Future_Performance_Log_MV1
Overvaluation
Overvaluation_x_Underperformance

Table 3: Market Value Tiers and Related Interactions

MV1_Tier_Low
MV1_Tier_Medium
MV1_Tier_High
MV1_Tier_Highest
Underperf_Low
Underperf_Medium
Underperf_High
Underperf_Highest

Table 4: Temporal and Age-Related Variables

Lagged_MV_Change
Lagged_Underperformance_Magnitude
Young_Underperform
Young_MV1

For correlation matrices, I suggest:
Correlation Matrix 1: Core Variables

Include all variables from Table 1

Correlation Matrix 2: Main Effects and Interactions

Selected key variables from Tables 1-4 that are most relevant to your main hypotheses
Include:

MV_Change
Overall_Performance_Index
Underperformance_Magnitude
Log_MV1
Age
Key interaction terms



This organization:

Groups related variables together
Keeps tables at a manageable size
Makes it easier for readers to find specific information
Supports the narrative flow of your analysis

Would you like me to provide LaTeX templates for these tables once you have the statistical values ready? Also, should we adjust any of these groupings based on the specific focus of your hypotheses? CopyRetryClaude can make mistakes. Please double-check responses.
